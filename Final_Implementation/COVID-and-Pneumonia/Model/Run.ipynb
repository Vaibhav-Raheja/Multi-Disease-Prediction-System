# %%
import fastai
from fastai import *
from fastai.vision import *
from fastai.metrics import error_rate
import torch
import pandas as pd
import numpy as np
import warnings
from fastai.tabular.data import *
warnings.filterwarnings('ignore')

# %%
#load model 
learn = load_learner("../Model",'Covid and Pnumonia_pytorch.json')
learn1 = load_learner("../Model",'Covid and Pnumonia_pytorch.model')

# %%
#Open Image

s1 = open_image('../Sathak/sarthak.jpg')
s2 = open_image('../Sathak/sarthak2.png')
s3 = open_image('../Sathak/sarthak3.png')
s4 = open_image('../Sathak/sarthak4.png')

# %%
# print("NORMAL TEST:")
# img_n.show()
# print(learn.predict(img_n)[0],"\n")

# print("COVID TEST:")
# img_c.show()
# print(learn.predict(img_c)[0],"\n")

# print("PNEUMONIA TEST:")
# img_p.show()
# p = learn.predict(img_p)[0]
# print(p,"\n")
s1.show()
print(learn.predict(s1)[0] ,learn.predict(s1)[2])
# Out:
# Normal tensor([0.2773, 0.4466, 0.2761])

# %%
s2.show()
print(learn.predict(s2)[0] ,learn.predict(s2))
# Out:
# COVID-19 (Category tensor(0), tensor(0), tensor([9.9915e-01, 8.2242e-04, 2.7990e-05]))

# %%
s3.show()
# print(learn.predict(s3)[0] ,learn.predict(s3))
print(learn.predict(s3))
# Out:
# (Category tensor(0), tensor(0), tensor([9.9999e-01, 1.3538e-05, 3.0604e-08]))

# %%
s4.show()
x = learn.predict(s4)[0]
print(x)
# Out:
# COVID-19
